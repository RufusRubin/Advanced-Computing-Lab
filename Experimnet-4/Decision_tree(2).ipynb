# %% [markdown]
# <a href="https://colab.research.google.com/github/RufusRubin/Advanced-Computing-Lab/blob/main/Experimnet-4/Decision_tree(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Load the data**

# %%
import pandas as pd

# %%
from sklearn.datasets import load_iris

# %%
data=load_iris()

# %%
x= data.data

# %%
y= data.target

# %% [markdown]
# **Train_text_split**

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=42)

# %% [markdown]
# **Model**

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model = DecisionTreeClassifier(criterion= 'entropy')

# %% [markdown]
# **Fit the model**

# %%
model = model.fit(x_train, y_train)

# %% [markdown]
# **Predict**

# %%
res= model.predict(x_test)
res
# Out:
# array([1, 0, 2, 1, 1, 0, 1, 2, 1, 1, 2, 0, 0, 0, 0, 1, 2, 1, 1, 2, 0, 2,
#        0, 2, 2, 2, 2, 2, 0, 0, 0, 0, 1, 0, 0, 2, 1, 0, 0, 0, 2, 1, 1, 0,
#        0, 1, 1, 2, 1, 2])

# %% [markdown]
# **Accuracy**

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy= accuracy_score(y_test,res)

# %%
print(accuracy*100)
# Out:
# 98.0

# %% [markdown]
# **Draw the graph**

# %%
from sklearn import tree
import graphviz
dot_data = tree.export_graphviz(model,filled=True)
graph = graphviz.Source(dot_data)
graph
