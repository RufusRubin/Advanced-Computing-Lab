# %% [markdown]
# <a href="https://colab.research.google.com/github/RufusRubin/Advanced-Computing-Lab/blob/main/Untitled21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# !pip install Augmentor
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
data="/content/drive/MyDrive/New folder/train/rufus"

# %%
data.shape()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-68-3d8483998d6f> in <module>()
# ----> 1 data.shape()
#
# AttributeError: 'str' object has no attribute 'shape'

# %%
import Augmentor
# Passing the path of the image directory
p = Augmentor.Pipeline("/content/drive/MyDrive/New folder/train/rufus")
  
# Defining augmentation parameters and generating 5 samples
p.flip_left_right(0.5)
p.black_and_white(0.1)
p.rotate(0.3, 10, 10)
p.skew(0.4, 0.5)
p.zoom(probability = 0.2, min_factor = 1.1, max_factor = 1.5)
p.sample(100)
# Out:
# Initialised with 20 image(s) found.
# Output directory set to /content/drive/MyDrive/New folder/train/rufus/output.
# Processing <PIL.Image.Image image mode=RGB size=1920x2560 at 0x7FDACF601C10>: 100%|██████████| 100/100 [00:55<00:00,  1.80 Samples/s]

# %%
p = Augmentor.Pipeline("/content/drive/MyDrive/New folder/train/sarath")
  
# Defining augmentation parameters and generating 5 samples
p.flip_left_right(0.5)
p.black_and_white(0.1)
p.rotate(0.3, 10, 10)
p.skew(0.4, 0.5)
p.zoom(probability = 0.2, min_factor = 1.1, max_factor = 1.5)
p.sample(100)
# Out:
# Initialised with 20 image(s) found.
# Output directory set to /content/drive/MyDrive/New folder/train/sarath/output.
# Processing <PIL.Image.Image image mode=1 size=3008x6528 at 0x7FDAD0140BD0>: 100%|██████████| 100/100 [03:41<00:00,  2.21s/ Samples]

# %%
# !rmdir /content/content/dataset_test/.ipynb_checkpoints
# Out:
# rmdir: failed to remove '/content/content/dataset_test/.ipynb_checkpoints': No such file or directory

# %%
from keras.preprocessing.image import ImageDataGenerator
train_datagen=ImageDataGenerator(rescale=1./255)
valid_datagen=ImageDataGenerator(rescale=1./255)

# %%
train_dir="/content/drive/MyDrive/New folder/train"
val_dir="/content/drive/MyDrive/New folder/test"

# %%
train_data=train_datagen.flow_from_directory(train_dir, target_size=(224, 224), class_mode='binary', batch_size=1,seed=42)
valid_data=valid_datagen.flow_from_directory(val_dir, target_size=(224, 224), class_mode='binary',batch_size=1,seed=42)
# Out:
# Found 240 images belonging to 2 classes.
# Found 20 images belonging to 2 classes.

# %%
model_1=tf.keras.models.Sequential([
                                    tf.keras.layers.Conv2D(filters=10,
                                                           kernel_size=3,
                                                           activation="relu",
                                                           input_shape=(224,224,3)),
                                    tf.keras.layers.Conv2D(10,3,activation="relu"),
                                    tf.keras.layers.MaxPool2D(pool_size=2,
                                                              padding="valid"),
                                    tf.keras.layers.Conv2D(10,3,activation="relu"),
                                    tf.keras.layers.Conv2D(10,3,activation="relu"),
                                    tf.keras.layers.MaxPool2D(2),
                                    tf.keras.layers.Flatten(),
                                    tf.keras.layers.Dense(1,activation="sigmoid")
                                    
                                    
                                    
])

# %%
model_1.compile(loss="binary_crossentropy",
                optimizer=tf.keras.optimizers.SGD(),
                metrics=["accuracy"])

# %%
callback = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=5)

# %%
history_1=model_1.fit(train_data,
                      epochs=50,
                      steps_per_epoch=50,
                      validation_data=valid_data,
                       callbacks=[callback]
                      )
# Out:
# Epoch 1/50
# 50/50 [==============================] - 22s 425ms/step - loss: 0.7022 - accuracy: 0.5400 - val_loss: 0.6699 - val_accuracy: 0.5000
# Epoch 2/50
# 50/50 [==============================] - 14s 287ms/step - loss: 0.6602 - accuracy: 0.7600 - val_loss: 0.5230 - val_accuracy: 0.8500
# Epoch 3/50
# 50/50 [==============================] - 14s 289ms/step - loss: 0.5220 - accuracy: 0.7800 - val_loss: 0.6922 - val_accuracy: 0.5000
# Epoch 4/50
# 50/50 [==============================] - 13s 261ms/step - loss: 0.6885 - accuracy: 0.6200 - val_loss: 0.6923 - val_accuracy: 0.5000
# Epoch 5/50
# 50/50 [==============================] - 14s 279ms/step - loss: 0.6886 - accuracy: 0.5200 - val_loss: 0.6775 - val_accuracy: 0.7500
# Epoch 6/50
# 50/50 [==============================] - 15s 302ms/step - loss: 0.6982 - accuracy: 0.6200 - val_loss: 0.6524 - val_accuracy: 0.9000
# Epoch 7/50
# ...

# %%
from tensorflow.keras.preprocessing import image
def predictImage(filename):
  img1=image.load_img(filename,target_size=(224,224))
  plt.imshow(img1)
  Y=image.img_to_array(img1)
  X=np.expand_dims(Y,axis=0)
  val=model_1.predict(X)
  
  print(val)
  print(val[[0]])
  if val>=0.5:
    plt.xlabel("sarath",fontsize=30)
  elif val<0.5:
    plt.xlabel("rufus",fontsize=30)

# %%
predictImage("/content/drive/MyDrive/New folder/test/sarath/IMG_20220715_150927.jpg")
# Out:
# [[1.]]
# [[1.]]

# %%
import matplotlib.pyplot as plt
import keras
from matplotlib import pyplot as plt
plt.plot(history_1.history['accuracy'])
plt.plot(history_1.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history_1.history['loss'])
plt.plot(history_1.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')

plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
model_2=tf.keras.models.Sequential([
                                    tf.keras.layers.Conv2D(filters=10,
                                                           kernel_size=3,
                                                           activation="relu",
                                                           input_shape=(224,224,3)),
                                    tf.keras.layers.Conv2D(10,3,activation="relu"),
                                    tf.keras.layers.MaxPool2D(pool_size=2,
                                                              padding="valid"),
                                    tf.keras.layers.Conv2D(10,3,activation="relu"),
                                    tf.keras.layers.Conv2D(10,3,activation="relu"),
                                    tf.keras.layers.MaxPool2D(2),
                                    tf.keras.layers.Flatten(),
                                    tf.keras.layers.Dense(1,activation="sigmoid")])

# %%
model_2.compile(loss="binary_crossentropy",
                optimizer=tf.keras.optimizers.Adam(),
                metrics=["accuracy"])

# %%
history_2=model_2.fit(train_data,
                      epochs=50,
                      steps_per_epoch=50,
                      validation_data=valid_data,
                       callbacks=[callback]
                      )
# Out:
# Epoch 1/50
# 50/50 [==============================] - 19s 347ms/step - loss: 0.7376 - accuracy: 0.5800 - val_loss: 0.5376 - val_accuracy: 0.8500
# Epoch 2/50
# 50/50 [==============================] - 17s 344ms/step - loss: 0.6428 - accuracy: 0.6400 - val_loss: 0.5494 - val_accuracy: 1.0000
# Epoch 3/50
# 50/50 [==============================] - 16s 331ms/step - loss: 0.5800 - accuracy: 0.7400 - val_loss: 0.3365 - val_accuracy: 0.9500
# Epoch 4/50
# 50/50 [==============================] - 14s 286ms/step - loss: 0.2593 - accuracy: 0.9600 - val_loss: 0.0176 - val_accuracy: 1.0000
# Epoch 5/50
# 50/50 [==============================] - 16s 316ms/step - loss: 0.0448 - accuracy: 0.9800 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 6/50
# 50/50 [==============================] - 19s 381ms/step - loss: 0.0232 - accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 7/50
# ...

# %%
from tensorflow.keras.preprocessing import image
def predictImage(filename):
  img1=image.load_img(filename,target_size=(224,224))
  plt.imshow(img1)
  Y=image.img_to_array(img1)
  X=np.expand_dims(Y,axis=0)
  val=model_2.predict(X)
  
  print(val)
  #print(val[[0]])
  if val>=0.5:
    plt.xlabel("sarath",fontsize=30)
  elif val<0.5:
    plt.xlabel("rufus",fontsize=30)

# %%
predictImage("/content/drive/MyDrive/New folder/test/rufus/IMG_20220717_124726.jpg")
# Out:
# [[6.217225e-08]]

# %%
import matplotlib.pyplot as plt
import keras
from matplotlib import pyplot as plt
plt.plot(history_2.history['accuracy'])
plt.plot(history_2.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history_2.history['loss'])
plt.plot(history_2.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')

plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
